# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_excel('BBC_gender_complete.xlsx')

# %%
df.head()
# Out:
#                     movie         director  movie_year        critic  \
# 0        Mulholland Drive      David Lynch      2001.0  Simon Abrams
# 1    In the Mood for Love     Wong Kar-wai      2000.0  Simon Abrams
# 2        The Tree of Life  Terrence Malick      2011.0  Simon Abrams
# 3  Yi Yi: A One and a Two      Edward Yang      2000.0  Simon Abrams
# 4     Goodbye to Language  Jean-Luc Godard      2014.0  Simon Abrams
#
#   critic_country             critic_org Bechdel_test director_gender
# 0             US  Freelance film critic         pass               M
# 1             US  Freelance film critic         pass               M
# 2             US  Freelance film critic       nopass               M
# 3             US  Freelance film critic         pass               M
# 4             US  Freelance film critic          NaN               M

# %%
df['movie_year'] = df['movie_year'].astype(int)
df['Bechdel_test'] = df['Bechdel_test'].replace(['nopass'],"didn't pass")
df['Bechdel_test'] = df['Bechdel_test'].replace(['pass'],"passed")
df['Bechdel_test'] = df['Bechdel_test'].fillna(value= "unknown")
df.head()
# Out:
#                     movie         director  movie_year        critic  \
# 0        Mulholland Drive      David Lynch        2001  Simon Abrams
# 1    In the Mood for Love     Wong Kar-wai        2000  Simon Abrams
# 2        The Tree of Life  Terrence Malick        2011  Simon Abrams
# 3  Yi Yi: A One and a Two      Edward Yang        2000  Simon Abrams
# 4     Goodbye to Language  Jean-Luc Godard        2014  Simon Abrams
#
#   critic_country             critic_org Bechdel_test director_gender
# 0             US  Freelance film critic       passed               M
# 1             US  Freelance film critic       passed               M
# 2             US  Freelance film critic  didn't pass               M
# 3             US  Freelance film critic       passed               M
# 4             US  Freelance film critic      unknown               M

# %%
df.movie.nunique()
# Out:
# 598

# %%
# the same director can have more than one movie in the list
df[df.director_gender=='M'].director.nunique()
# Out:
# 353

# %%
df[df.director_gender=='F'].director.nunique()
# Out:
# 48

# %%
df_final = df[(df.director_gender== 'F') | (df.director_gender== 'Both')]
df_final.head()
# Out:
#                movie         director  movie_year            critic  \
# 20  Zero Dark Thirty  Kathryn Bigelow        2012      Thelma Adams
# 23   Stories We Tell     Sarah Polley        2012      Thelma Adams
# 28      Frozen River    Courtney Hunt        2008      Thelma Adams
# 42   American Psycho      Mary Harron        2000  Matthew Anderson
# 46           Lourdes  Jessica Hausner        2009  Matthew Anderson
#
#    critic_country             critic_org Bechdel_test director_gender
# 20             US  Freelance film critic       passed               F
# 23             US  Freelance film critic       passed               F
# 28             US  Freelance film critic       passed               F
# 42             UK            BBC Culture       passed               F
# 46             UK            BBC Culture       passed               F

# %%
df_final.Bechdel_test.value_counts(normalize=True) *100
# Out:
# passed         65.644172
# didn't pass    17.791411
# unknown        16.564417
# Name: Bechdel_test, dtype: float64

# %%
df_final.head()
# Out:
#                movie         director  movie_year            critic  \
# 20  Zero Dark Thirty  Kathryn Bigelow        2012      Thelma Adams
# 23   Stories We Tell     Sarah Polley        2012      Thelma Adams
# 28      Frozen River    Courtney Hunt        2008      Thelma Adams
# 42   American Psycho      Mary Harron        2000  Matthew Anderson
# 46           Lourdes  Jessica Hausner        2009  Matthew Anderson
#
#    critic_country             critic_org Bechdel_test director_gender
# 20             US  Freelance film critic       passed               F
# 23             US  Freelance film critic       passed               F
# 28             US  Freelance film critic       passed               F
# 42             UK            BBC Culture       passed               F
# 46             UK            BBC Culture       passed               F

# %% [markdown]
# ### The idea is to create a map of countries where movies from female directors were chosen among the '21st Century best movies'. We simply don't know who most of those directors are because they didn't make it to the 100 movies ranking !!
# ### We also analyze if those movies generally do pass or not the Bechdel test

# %%
df1 = df_final.groupby(['critic_country', 'director_gender', 'director', 'Bechdel_test', 'movie_year'])['movie'].value_counts().reset_index(name='count')

# %%
df1
# Out:
#     critic_country director_gender            director Bechdel_test  \
# 0        Australia               F       Jennifer Kent       passed
# 1        Australia               F  Rita Azevedo Gomes       passed
# 2          Austria               F     Lucrecia Martel       passed
# 3          Austria               F           Maren Ade       passed
# 4          Austria               F   Valeska Grisebach      unknown
# ..             ...             ...                 ...          ...
# 127             US               F        Sarah Polley       passed
# 128             US               F        Sarah Polley       passed
# 129             US               F       Sofia Coppola       passed
# 130             US               F       Sofia Coppola       passed
# 131             US               F        Susanne Bier  didn't pass
#
#      movie_year                     movie  count
# 0          2014              The Babadook      1
# 1          2012  A Vingança de Uma Mulher      1
# 2          2004             The Holy Girl      1
# 3          2016              Toni Erdmann      1
# 4          2006                   Longing      1
# ..          ...                       ...    ...
# 127        2011           Take This Waltz      1
# 128        2012           Stories We Tell      4
# 129        2003       Lost in Translation      7
# 130        2010                 Somewhere      2
# 131        2006         After the Wedding      1
#
# [132 rows x 7 columns]

# %%
df1["string"] = df1["movie"] +" (" + df1["movie_year"].astype(str)+ ") "+ "by " + df1["director"] + ": " + df1["count"].map(str) + np.where(df1["count"] >1, ' votes', ' vote')

# %% [markdown]
# ### How many movies did pass the Bechdel test? The color of the country (green, orange, red) gives you a hint

# %%
body = df1.groupby('critic_country')['string'].apply(lambda x: "<div id='movie'><h1><b>Top Movies by Female Directors</b></h1><P>{0}</P></div>".format('</p><p> '.join(x))).reset_index(name='properties.article')

# %%
body
# Out:
#    critic_country                                 properties.article
# 0       Australia  <div id='movie'><h1><b>Top Movies by Female Di...
# 1         Austria  <div id='movie'><h1><b>Top Movies by Female Di...
# 2          Brazil  <div id='movie'><h1><b>Top Movies by Female Di...
# 3          Canada  <div id='movie'><h1><b>Top Movies by Female Di...
# 4           China  <div id='movie'><h1><b>Top Movies by Female Di...
# 5        Colombia  <div id='movie'><h1><b>Top Movies by Female Di...
# 6            Cuba  <div id='movie'><h1><b>Top Movies by Female Di...
# 7           Egypt  <div id='movie'><h1><b>Top Movies by Female Di...
# 8          France  <div id='movie'><h1><b>Top Movies by Female Di...
# 9         Germany  <div id='movie'><h1><b>Top Movies by Female Di...
# 10      Hong Kong  <div id='movie'><h1><b>Top Movies by Female Di...
# 11          India  <div id='movie'><h1><b>Top Movies by Female Di...
# 12      Indonesia  <div id='movie'><h1><b>Top Movies by Female Di...
# 13         Israel  <div id='movie'><h1><b>Top Movies by Female Di...
# 14          Italy  <div id='movie'><h1><b>Top Movies by Female Di...
# 15        Lebanon  <div id='movie'><h1><b>Top Movies by Female Di...
# 16        Namibia  <div id='movie'><h1><b>Top Movies by Female Di...
# 17      Singapore  <div id='movie'><h1><b>Top Movies by Female Di...
# 18   South Africa  <div id='movie'><h1><b>Top Movies by Female Di...
# 19         Turkey  <div id='movie'><h1><b>Top Movies by Female Di...
# 20            UAE  <div id='movie'><h1><b>Top Movies by Female Di...
# 21             UK  <div id='movie'><h1><b>Top Movies by Female Di...
# 22             US  <div id='movie'><h1><b>Top Movies by Female Di...

# %%
body.iloc[17]['properties.article']
# Out:
# "<div id='movie'><h1><b>Top Movies by Female Directors</b></h1><P>A Girl Walks Home Alone at Night (2014) by Ana Lily Amirpour: 1 vote</p><p> We Need to Talk About Kevin (2011) by Lynne Ramsay: 1 vote</P></div>"

# %%
df2 = df_final.groupby('critic_country')['Bechdel_test'].value_counts().reset_index(name='count')
df2.head()
# Out:
#   critic_country Bechdel_test  count
# 0      Australia       passed      2
# 1        Austria       passed      2
# 2        Austria      unknown      1
# 3         Brazil  didn't pass      1
# 4         Canada       passed      6

# %%
df2["string"] = df2["count"].map(str) + np.where(df2["count"] >1, ' movies', ' movie') + " " + df2['Bechdel_test']

# %%
header = df2.groupby('critic_country')['string'].apply(lambda x: "<div id='test_result'><h2><b>How many did pass the Bechdel test?</b></h2><P>{0}</P></div>".format('</p><p> '.join(x))).reset_index(name='properties.headline')
header
# Out:
#    critic_country                                properties.headline
# 0       Australia  <div id='test_result'><h2><b>How many did pass...
# 1         Austria  <div id='test_result'><h2><b>How many did pass...
# 2          Brazil  <div id='test_result'><h2><b>How many did pass...
# 3          Canada  <div id='test_result'><h2><b>How many did pass...
# 4           China  <div id='test_result'><h2><b>How many did pass...
# 5        Colombia  <div id='test_result'><h2><b>How many did pass...
# 6            Cuba  <div id='test_result'><h2><b>How many did pass...
# 7           Egypt  <div id='test_result'><h2><b>How many did pass...
# 8          France  <div id='test_result'><h2><b>How many did pass...
# 9         Germany  <div id='test_result'><h2><b>How many did pass...
# 10      Hong Kong  <div id='test_result'><h2><b>How many did pass...
# 11          India  <div id='test_result'><h2><b>How many did pass...
# 12      Indonesia  <div id='test_result'><h2><b>How many did pass...
# 13         Israel  <div id='test_result'><h2><b>How many did pass...
# 14          Italy  <div id='test_result'><h2><b>How many did pass...
# 15        Lebanon  <div id='test_result'><h2><b>How many did pass...
# 16        Namibia  <div id='test_result'><h2><b>How many did pass...
# 17      Singapore  <div id='test_result'><h2><b>How many did pass...
# 18   South Africa  <div id='test_result'><h2><b>How many did pass...
# 19         Turkey  <div id='test_result'><h2><b>How many did pass...
# 20            UAE  <div id='test_result'><h2><b>How many did pass...
# 21             UK  <div id='test_result'><h2><b>How many did pass...
# 22             US  <div id='test_result'><h2><b>How many did pass...

# %%
header.iloc[17]['properties.headline']
# Out:
# "<div id='test_result'><h2><b>How many did pass the Bechdel test?</b></h2><P>2 movies passed</P></div>"

# %%
output = body.merge(header, how='left', on='critic_country')

# %%
output
# Out:
#    critic_country                                 properties.article  \
# 0       Australia  <div id='movie'><h1><b>Top Movies by Female Di...
# 1         Austria  <div id='movie'><h1><b>Top Movies by Female Di...
# 2          Brazil  <div id='movie'><h1><b>Top Movies by Female Di...
# 3          Canada  <div id='movie'><h1><b>Top Movies by Female Di...
# 4           China  <div id='movie'><h1><b>Top Movies by Female Di...
# 5        Colombia  <div id='movie'><h1><b>Top Movies by Female Di...
# 6            Cuba  <div id='movie'><h1><b>Top Movies by Female Di...
# 7           Egypt  <div id='movie'><h1><b>Top Movies by Female Di...
# 8          France  <div id='movie'><h1><b>Top Movies by Female Di...
# 9         Germany  <div id='movie'><h1><b>Top Movies by Female Di...
# 10      Hong Kong  <div id='movie'><h1><b>Top Movies by Female Di...
# 11          India  <div id='movie'><h1><b>Top Movies by Female Di...
# 12      Indonesia  <div id='movie'><h1><b>Top Movies by Female Di...
# 13         Israel  <div id='movie'><h1><b>Top Movies by Female Di...
# 14          Italy  <div id='movie'><h1><b>Top Movies by Female Di...
# 15        Lebanon  <div id='movie'><h1><b>Top Movies by Female Di...
# 16        Namibia  <div id='movie'><h1><b>Top Movies by Female Di...
# 17      Singapore  <div id='movie'><h1><b>Top Movies by Female Di...
# 18   South Africa  <div id='movie'><h1><b>Top Movies by Female Di...
# 19         Turkey  <div id='movie'><h1><b>Top Movies by Female Di...
# 20            UAE  <div id='movie'><h1><b>Top Movies by Female Di...
# 21             UK  <div id='movie'><h1><b>Top Movies by Female Di...
# 22             US  <div id='movie'><h1><b>Top Movies by Female Di...
#
#                                   properties.headline
# 0   <div id='test_result'><h2><b>How many did pass...
# 1   <div id='test_result'><h2><b>How many did pass...
# 2   <div id='test_result'><h2><b>How many did pass...
# 3   <div id='test_result'><h2><b>How many did pass...
# 4   <div id='test_result'><h2><b>How many did pass...
# 5   <div id='test_result'><h2><b>How many did pass...
# 6   <div id='test_result'><h2><b>How many did pass...
# 7   <div id='test_result'><h2><b>How many did pass...
# 8   <div id='test_result'><h2><b>How many did pass...
# 9   <div id='test_result'><h2><b>How many did pass...
# 10  <div id='test_result'><h2><b>How many did pass...
# 11  <div id='test_result'><h2><b>How many did pass...
# 12  <div id='test_result'><h2><b>How many did pass...
# 13  <div id='test_result'><h2><b>How many did pass...
# 14  <div id='test_result'><h2><b>How many did pass...
# 15  <div id='test_result'><h2><b>How many did pass...
# 16  <div id='test_result'><h2><b>How many did pass...
# 17  <div id='test_result'><h2><b>How many did pass...
# 18  <div id='test_result'><h2><b>How many did pass...
# 19  <div id='test_result'><h2><b>How many did pass...
# 20  <div id='test_result'><h2><b>How many did pass...
# 21  <div id='test_result'><h2><b>How many did pass...
# 22  <div id='test_result'><h2><b>How many did pass...

# %%
def rand_color():
    letters = 'ABCDEF'
    import random
    from random import randint
    this_letter = random.choice(letters)
    random_num1 = randint(0,9)
    random_num2 = randint(0,9)
    hexColor = '#' + this_letter + this_letter + str(random_num1)+ str(random_num1)+ str(random_num2)+ str(random_num2)
    return hexColor

# %%
output['properties.color'] = output.apply(lambda x: rand_color(), axis=1)

# %%
output['critic_country'] = output['critic_country'].replace(['UAE'],"United Arab Emirates")
output['critic_country'] = output['critic_country'].replace(['UK'],"United Kingdom")
output['critic_country'] = output['critic_country'].replace(['US'],"United States")

# %%
output.head()
# Out:
#   critic_country                                 properties.article  \
# 0      Australia  <div id='movie'><h1><b>Top Movies by Female Di...
# 1        Austria  <div id='movie'><h1><b>Top Movies by Female Di...
# 2         Brazil  <div id='movie'><h1><b>Top Movies by Female Di...
# 3         Canada  <div id='movie'><h1><b>Top Movies by Female Di...
# 4          China  <div id='movie'><h1><b>Top Movies by Female Di...
#
#                                  properties.headline properties.color
# 0  <div id='test_result'><h2><b>How many did pass...          #FF6699
# 1  <div id='test_result'><h2><b>How many did pass...          #AA6666
# 2  <div id='test_result'><h2><b>How many did pass...          #AA4499
# 3  <div id='test_result'><h2><b>How many did pass...          #BB7799
# 4  <div id='test_result'><h2><b>How many did pass...          #FF5577

# %%
output.rename(columns={'critic_country': 'properties.name'}, inplace=True)

# %%
output.head()
# Out:
#   properties.name                                 properties.article  \
# 0       Australia  <div id='movie'><h1><b>Top Movies by Female Di...
# 1         Austria  <div id='movie'><h1><b>Top Movies by Female Di...
# 2          Brazil  <div id='movie'><h1><b>Top Movies by Female Di...
# 3          Canada  <div id='movie'><h1><b>Top Movies by Female Di...
# 4           China  <div id='movie'><h1><b>Top Movies by Female Di...
#
#                                  properties.headline properties.color
# 0  <div id='test_result'><h2><b>How many did pass...          #FF6699
# 1  <div id='test_result'><h2><b>How many did pass...          #AA6666
# 2  <div id='test_result'><h2><b>How many did pass...          #AA4499
# 3  <div id='test_result'><h2><b>How many did pass...          #BB7799
# 4  <div id='test_result'><h2><b>How many did pass...          #FF5577

# %%
#backup your dataframes
output.to_csv('output_dataframe_final.csv', index=False)
